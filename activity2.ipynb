# %%
print("Hello World")
# Out:
# Hello World

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\quijano\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
birds = pd.read_csv('datasets\\penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1> CHECKING your DATA FRAME for null values and data types <h1/>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
birds.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1> DESCRIPTIVE ANALYTICS<h1/>

# %%
birds.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h1> FILTERING DATA BASED FROM COLUMNS<h1/>

# %%
birds['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 1)

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# <h1> WHAT TO DO WITH NULL VALUES <h1/>

# %% [markdown]
# delete the row
#
# fill the empty cells with value

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds['weight'] = birds['weight'].fillna(birds['weight'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds['species'] = birds['species'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['sex'] = birds['sex'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
birds.head(25)
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1      2  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2      3  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3      4  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4      5  Adelie  Torgersen        36.70000       19.30000         193.000000
# 5      6  Adelie  Torgersen        39.30000       20.60000         190.000000
# 6      7  Adelie  Torgersen        38.90000       17.80000         181.000000
# 7      8  Adelie  Torgersen        39.20000       19.60000         195.000000
# 8      9  Adelie  Torgersen        34.10000       18.10000         193.000000
# 9     10  Adelie  Torgersen        42.00000       20.20000         190.000000
# 10    11  Adelie  Torgersen        37.80000       17.10000         186.000000
# ...

# %%
birds.tail(10)
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 334   335  Chinstrap  Dream            50.2           18.8              202.0
# 335   336  Chinstrap  Dream            45.6           19.4              194.0
# 336   337  Chinstrap  Dream            51.9           19.5              206.0
# 337   338  Chinstrap  Dream            46.8           16.5              189.0
# 338   339  Chinstrap  Dream            45.7           17.0              195.0
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year  weight
# 334       3800.0    male  2009     3.8
# ...

# %%
birds['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %%
birds[birds['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
birds[birds['species'] == "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %%
birds[birds['weight'] < 3].count()
# Out:
# rowid                8
# species              8
# island               8
# bill_length_mm       8
# bill_depth_mm        8
# flipper_length_mm    8
# body_mass_g          8
# sex                  8
# year                 8
# weight               8
# dtype: int64

# %%
birds['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
birds['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
birds['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == "Gentoo"]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
birds['island'] == "Biscoe"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
birds[birds['island'] == "Biscoe"]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe        37.80000       18.30000         174.000000
# 21     22  Adelie  Biscoe        37.70000       18.70000         180.000000
# 22     23  Adelie  Biscoe        35.90000       19.20000         189.000000
# 23     24  Adelie  Biscoe        38.20000       18.10000         185.000000
# 24     25  Adelie  Biscoe        38.80000       17.20000         180.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
(birds['species'] == "Gentoo") & (birds['island'] == "Biscoe")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
birds[(birds['species'] == "Gentoo") & (birds['island'] == "Biscoe")]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
birds[(birds['species'] == "Gentoo") & (birds['island'] == "Biscoe")]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
birds['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: category
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
birds['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
birds['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
np.round(birds['weight'], 1)
# Out:
# 0      3.8
# 1      3.8
# 2      3.2
# 3      4.2
# 4      3.4
#       ...
# 339    4.0
# 340    3.4
# 341    3.8
# 342    4.1
# 343    3.8
# Name: weight, Length: 344, dtype: float64

# %% [markdown]
# <h1> INSIGHT no.1 <h1\>
#
# <h2>Adelie lives in every island<h2\>

# %% [markdown]
# <h1> Adelie<h1\>

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
adelie_torgersen = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
adelie_biscoe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 20 to 115
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              44 non-null     category
#  1   species            44 non-null     category
#  2   island             44 non-null     category
#  3   bill_length_mm     44 non-null     float64
#  4   bill_depth_mm      44 non-null     float64
#  5   flipper_length_mm  44 non-null     float64
#  6   body_mass_g        44 non-null     float64
#  7   sex                44 non-null     category
#  8   year               44 non-null     category
#  9   weight             44 non-null     float64
# dtypes: category(5), float64(5)
# memory usage: 13.6 KB

# %%
adelie_dream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 30 to 151
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              56 non-null     category
#  1   species            56 non-null     category
#  2   island             56 non-null     category
#  3   bill_length_mm     56 non-null     float64
#  4   bill_depth_mm      56 non-null     float64
#  5   flipper_length_mm  56 non-null     float64
#  6   body_mass_g        56 non-null     float64
#  7   sex                56 non-null     category
#  8   year               56 non-null     category
#  9   weight             56 non-null     float64
# dtypes: category(5), float64(5)
# memory usage: 14.2 KB

# %%
adelie_torgersen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 131
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              52 non-null     category
#  1   species            52 non-null     category
#  2   island             52 non-null     category
#  3   bill_length_mm     52 non-null     float64
#  4   bill_depth_mm      52 non-null     float64
#  5   flipper_length_mm  52 non-null     float64
#  6   body_mass_g        52 non-null     float64
#  7   sex                52 non-null     category
#  8   year               52 non-null     category
#  9   weight             52 non-null     float64
# dtypes: category(5), float64(5)
# memory usage: 14.0 KB

# %% [markdown]
# <h1> INSIGHT no.2 <h1\>
#
# <h2>Chinstrap lives exclusively in Dream Island<h2\>

# %% [markdown]
# <h1> Chinstrap<h1\>

# %%
chinstrap_torgersen = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Torgersen')]

# %%
chinstrap_dream = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Dream')]

# %%
chinstrap_biscoe = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Biscoe')]

# %%
chinstrap_torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
chinstrap_dream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68 entries, 276 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              68 non-null     category
#  1   species            68 non-null     category
#  2   island             68 non-null     category
#  3   bill_length_mm     68 non-null     float64
#  4   bill_depth_mm      68 non-null     float64
#  5   flipper_length_mm  68 non-null     float64
#  6   body_mass_g        68 non-null     float64
#  7   sex                68 non-null     category
#  8   year               68 non-null     category
#  9   weight             68 non-null     float64
# dtypes: category(5), float64(5)
# memory usage: 14.9 KB

# %%
chinstrap_biscoe
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %% [markdown]
# <h1> INSIGHT no.3 <h1\>
#
# <h2>Gentoo lives exclusively in Biscoe Island<h2\>

# %% [markdown]
# <h1> Gentoo <h1\>

# %%
gentoo_biscoe = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')]

# %%
gentoo_dream = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Dream')]

# %%
gentoo_torgersen = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Torgersen')]

# %%
gentoo_biscoe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 152 to 275
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              124 non-null    category
#  1   species            124 non-null    category
#  2   island             124 non-null    category
#  3   bill_length_mm     124 non-null    float64
#  4   bill_depth_mm      124 non-null    float64
#  5   flipper_length_mm  124 non-null    float64
#  6   body_mass_g        124 non-null    float64
#  7   sex                124 non-null    category
#  8   year               124 non-null    category
#  9   weight             124 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 17.8 KB

# %%
gentoo_dream
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
gentoo_torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %% [markdown]
# <h1> INSIGHT no.4 <h1\>
#
# <h2>The islands doesn't have an impact in terms of the weight of the Adelie specie<h2\>

# %%
adelie_bisco_w = np.round(adelie_biscoe['weight'].mean(),1)

# %%
adelie_bisco_w
# Out:
# np.float64(3.7)

# %%
adelie_dream_w = np.round(adelie_dream['weight'].mean(), 1)

# %%
adelie_dream_w
# Out:
# np.float64(3.7)

# %%
adelie_torgersen_w = np.round(adelie_torgersen['weight'].mean(), 1)

# %%
adelie_torgersen_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1> INSIGHT no.5 <h1\>
#
# <h2>The island doesn't have an impact in terms of the weight of the Chinstrap specie<h2\>

# %%
chinstrap_dream_w = np.round(chinstrap_dream['weight'].mean(), 1)

# %%
chinstrap_dream_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1> INSIGHT no.6 <h1\>
#
# <h2>The island does have an impact in terms of the weight of the Gentoo specie<h2\>

# %%
gentoo_biscoe_w = np.round(gentoo_biscoe['weight'].mean(), 1)

# %%
gentoo_biscoe_w
# Out:
# np.float64(5.1)

# %% [markdown]
# <h1> INSIGHT no.7 <h1\>
#
# <h2>Gentoo is the heaviest among the species<h2\>

# %% [markdown]
# <h1> INSIGHT no.8 <h1\>
#
# <h2>Both year 2007 and 2009 in DREAM island<h2\>

# %%
penguins_agg = birds.groupby(['species', 'sex', 'island', 'year']).size()
# Out:
# C:\Users\QUIJANO\AppData\Local\Temp\ipykernel_456\3595821436.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg = birds.groupby(['species', 'sex', 'island', 'year']).size()

# %%
penguins_agg.unstack()
# Out:
# year                        2007  2008  2009
# species   sex    island
# Adelie    female Biscoe        5     9     8
#                  Dream         9     8    10
#                  Torgersen     8     8     8
#           male   Biscoe        5     9     8
#                  Dream        11     8    10
#                  Torgersen    12     8     8
# Chinstrap female Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
#           male   Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
# Gentoo    female Biscoe       16    22    20
#                  Dream         0     0     0
#                  Torgersen     0     0     0
#           male   Biscoe       18    24    24
#                  Dream         0     0     0
#                  Torgersen     0     0     0

# %% [markdown]
# <h1> INSIGHT no.9 <h1\>
# <h2>The average weight for Adelie: male 4kg female 3.4kg<h2\>

# %% [markdown]
# <h1> INSIGHT no.10 <h1\>
# <h2>The average weight for Chinstrap: male 3.9kg female 3.5kg<h2\>

# %% [markdown]
# <h1> INSIGHT no.11 <h1\>
# <h2>The average weight for Gentoo: male 5kg female 5kg<h2\>

# %%
penguins_agg2 = np.round(birds.groupby(['species', 'sex'])['weight'].mean(), 1)
# Out:
# C:\Users\QUIJANO\AppData\Local\Temp\ipykernel_456\1018957656.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg2 = np.round(birds.groupby(['species', 'sex'])['weight'].mean(), 1)

# %%
penguins_agg2
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.4
# Name: weight, dtype: float64
